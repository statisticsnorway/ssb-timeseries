# %%
import pandas as pd

# %%
data1 = {
    "periode": ['2023-01', '2023-02', '2023-03'],
    "verdi": [234, 543, 643],
    "user": ['1', '1', '1']
}

data2 = {
    "periode": ['2023-02', '2023-03', '2023-04'],
    "verdi": [543, 650, 712],
    "user": ['2', '2', '2']
}

# %%
df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# %%
df1

# %%
df2

# %%
df1.merge(df2, how='outer', on=['periode'], indicator=True)

# %%
df2.loc[df2['periode'].isin(df1['periode'])]

# %%
df1.merge(df2, on=['periode'])

# %%
df1[(~df1.periode.isin(common.col1))&(~df1.verdi.isin(common.col2))]

# %%
df1[~df2[['periode', 'verdi']].isin(df1[['periode', 'verdi']])]

# %%
df_all = df1.merge(df2.drop_duplicates(), on=['periode', 'verdi'], 
                   how='left', indicator=True)
df_all

# %%
map_periode = df2.periode.isin(df1.periode)
map_verdi = df2.verdi.isin(df1.verdi)
map_isin = map_periode & map_verdi
map_isnotin = ~map_isin

# %%
df2[map_isin]

# %%
df2[map_isnotin]

# %%
df1

# %%
df2
